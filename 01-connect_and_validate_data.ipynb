# %% [markdown]
# ![Alt text](images/banner.png)

# %% [markdown]
# ## Connection and Data Validation Notebook

# %% [markdown]
# ### Load the Credentials
#
# These environment variables are automatically set in WS Pipelines and are needed to access various services.

# %%
import os
TOKEN = os.getenv("USER_ACCESS_TOKEN")

# %%
## Imports

# !pip install tensorflow-data-validation==1.14.0
# !pip install ibm-watson-studio-pipelines==0.2.12
# !pip install python-dotenv==1.0.0
# Out:
# Collecting tensorflow-data-validation==1.14.0
#   Downloading tensorflow_data_validation-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 62.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas<2,>=1.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow-data-validation==1.14.0) (1.5.3)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow-data-validation==1.14.0) (1.0.0)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow-data-validation==1.14.0) (4.21.12)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 94.6 MB/s eta 0:00:00
# Collecting tensorflow<3,>=2.13
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 4.9 MB/s eta 0:00:0000:0100:01
# Collecting tfx-bsl<1.15,>=1.14.0
#   Downloading tfx_bsl-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 37.3 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-metadata<1.15,>=1.14.0
#   Downloading tensorflow_metadata-1.14.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow-data-validation==1.14.0) (1.23.5)
# Collecting pyarrow<11,>=10
#   Downloading pyarrow-10.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 59.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six<2,>=1.12 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow-data-validation==1.14.0) (1.16.0)
# Collecting apache-beam[gcp]<3,>=2.47
#   Downloading apache_beam-2.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 111.5 MB/s eta 0:00:0000:0100:01
# Collecting pyfarmhash<0.4,>=0.2.2
#   Downloading pyfarmhash-0.3.2.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.9/99.9 kB 44.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz>=2018.3 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2022.7)
# Collecting protobuf<5,>=3.20.3
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 111.0 MB/s eta 0:00:00
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 159.6 MB/s eta 0:00:00
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 19.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2.29.0)
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.22.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 25.6 MB/s eta 0:00:00
# Collecting objsize<0.7.0,>=0.6.1
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: cloudpickle~=2.2.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2.2.1)
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 90.0 MB/s eta 0:00:00
# Collecting httplib2<0.23.0,>=0.8
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 45.7 MB/s eta 0:00:00
# Collecting orjson<4,>=3.9.7
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 61.7 MB/s eta 0:00:00
# Collecting fasteners<1.0,>=0.3
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Collecting crcmod<2.0,>=1.7
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 42.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=22.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (23.0)
# Collecting pydot<2,>=1.2.0
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 65.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex>=2020.6.8 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2023.3.23)
# Requirement already satisfied: typing-extensions>=3.7.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (4.4.0)
# Collecting pymongo<5.0.0,>=3.8.0
#   Downloading pymongo-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 141.0 MB/s eta 0:00:00
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (1.51.3)
# Collecting js2py<1,>=0.74
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 137.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2.8.2)
# Collecting google-api-core<3,>=2.0.0
#   Downloading google_api_core-2.12.0-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 53.3 MB/s eta 0:00:00
# Collecting google-cloud-bigquery-storage<3,>=2.6.3
#   Downloading google_cloud_bigquery_storage-2.22.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 67.6 MB/s eta 0:00:00
# Collecting google-cloud-recommendations-ai<0.11.0,>=0.1.0
#   Downloading google_cloud_recommendations_ai-0.10.5-py2.py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 67.2 MB/s eta 0:00:00
# Collecting google-cloud-bigtable<3,>=2.19.0
#   Downloading google_cloud_bigtable-2.21.0-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.0/293.0 kB 73.6 MB/s eta 0:00:00
# Collecting google-cloud-language<3,>=2.0
#   Downloading google_cloud_language-2.11.1-py2.py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 44.7 MB/s eta 0:00:00
# Collecting google-cloud-aiplatform<2.0,>=1.26.0
#   Downloading google_cloud_aiplatform-1.35.0-py2.py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 54.7 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: google-auth<3,>=1.18.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2.6.0)
# Collecting google-cloud-spanner<4,>=3.0.0
#   Downloading google_cloud_spanner-3.40.1-py2.py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.9/332.9 kB 84.3 MB/s eta 0:00:00
# Collecting google-cloud-bigquery<4,>=2.0.0
#   Downloading google_cloud_bigquery-3.12.0-py2.py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.4/220.4 kB 74.0 MB/s eta 0:00:00
# Collecting google-cloud-videointelligence<3,>=2.0
#   Downloading google_cloud_videointelligence-2.11.4-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.5/229.5 kB 66.8 MB/s eta 0:00:00
# Collecting google-cloud-datastore<3,>=2.0.0
#   Downloading google_cloud_datastore-2.18.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.3/177.3 kB 64.6 MB/s eta 0:00:00
# Collecting google-apitools<0.5.32,>=0.5.31
#   Downloading google-apitools-0.5.31.tar.gz (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 kB 25.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting google-cloud-pubsub<3,>=2.1.0
#   Downloading google_cloud_pubsub-2.18.4-py2.py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 98.1 MB/s eta 0:00:00
# Collecting google-cloud-pubsublite<2,>=1.2.0
#   Downloading google_cloud_pubsublite-1.8.3-py2.py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.1/288.1 kB 93.1 MB/s eta 0:00:00
# Collecting google-auth-httplib2<0.2.0,>=0.1.0
#   Downloading google_auth_httplib2-0.1.1-py2.py3-none-any.whl (9.3 kB)
# Collecting google-cloud-vision<4,>=2
#   Downloading google_cloud_vision-3.4.5-py2.py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.1/444.1 kB 81.0 MB/s eta 0:00:00
# Collecting google-cloud-dlp<4,>=3.0.0
#   Downloading google_cloud_dlp-3.12.3-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 52.4 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6,>=3.1.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (4.2.2)
# Collecting google-cloud-core<3,>=2.0.0
#   Downloading google_cloud_core-2.3.3-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (3.3.0)
# Collecting ml-dtypes==0.2.0
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 150.1 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (3.7.0)
# Collecting tensorflow-estimator<2.15,>=2.14.0
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 87.1 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (1.1.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (65.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (0.32.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 54.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (1.6.3)
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting keras<2.15,>=2.14.0
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 124.1 MB/s eta 0:00:00
# Collecting tensorboard<2.15,>=2.14
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 139.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorflow-metadata<1.15,>=1.14.0->tensorflow-data-validation==1.14.0) (1.56.4)
# Collecting protobuf<5,>=3.20.3
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 107.9 MB/s eta 0:00:00
# Collecting google-api-python-client<2,>=1.7.11
#   Downloading google_api_python_client-1.12.11-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 31.6 MB/s eta 0:00:00
# Collecting tensorflow-serving-api<3,>=2.13.0
#   Downloading tensorflow_serving_api-2.14.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (0.38.4)
# Collecting google-auth<3,>=1.18.0
#   Downloading google_auth-2.23.3-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 63.7 MB/s eta 0:00:00
# Collecting uritemplate<4dev,>=3.0.0
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Collecting oauth2client>=1.4.12
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (4.7.2)
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3
#   Downloading google_cloud_resource_manager-1.10.4-py2.py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.0/321.0 kB 91.8 MB/s eta 0:00:00
# Collecting shapely<3.0.0dev
#   Downloading shapely-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 112.8 MB/s eta 0:00:00
# Collecting google-cloud-storage<3.0.0dev,>=1.32.0
#   Downloading google_cloud_storage-2.12.0-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 54.5 MB/s eta 0:00:00
# Collecting google-resumable-media<3.0dev,>=0.6.0
#   Downloading google_resumable_media-2.6.0-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 40.2 MB/s eta 0:00:00
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4
#   Downloading grpc_google_iam_v1-0.12.6-py2.py3-none-any.whl (26 kB)
# Collecting grpcio-status>=1.33.2
#   Downloading grpcio_status-1.59.0-py3-none-any.whl (14 kB)
# Collecting overrides<7.0.0,>=6.0.1
#   Downloading overrides-6.5.0-py3-none-any.whl (17 kB)
# Collecting sqlparse>=0.4.4
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 14.1 MB/s eta 0:00:00
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from httplib2<0.23.0,>=0.8->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (3.0.9)
# Collecting pyjsparser>=2.5.1
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tzlocal>=1.2
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 95.2 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (2023.5.7)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (0.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (0.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (3.3.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (1.3.0)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Collecting grpcio-status>=1.33.2
#   Downloading grpcio_status-1.58.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.57.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.56.2-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.56.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.55.3-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.54.3-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.54.2-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.54.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.53.2-py3-none-any.whl (5.1 kB)
# Collecting grpcio!=1.48.0,<2,>=1.33.1
#   Downloading grpcio-1.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 98.0 MB/s eta 0:00:00ta 0:00:01
# Collecting grpcio-status>=1.33.2
#   Downloading grpcio_status-1.53.1-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.53.0-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.51.3-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.51.1-py3-none-any.whl (5.1 kB)
#   Downloading grpcio_status-1.50.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.49.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.48.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47->tensorflow-data-validation==1.14.0) (0.4.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (2.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow<3,>=2.13->tensorflow-data-validation==1.14.0) (3.2.2)
# Building wheels for collected packages: pyfarmhash, crcmod, dill, google-apitools, hdfs, pyjsparser, docopt
#   Building wheel for pyfarmhash (setup.py) ... done
#   Created wheel for pyfarmhash: filename=pyfarmhash-0.3.2-cp310-cp310-linux_x86_64.whl size=14065 sha256=808ff3c83afdc3bac95db9f529422dbba540151fc44204b84132af24010e1b14
#   Stored in directory: /tmp/1000800000/.cache/pip/wheels/e0/08/da/f66b1f3258fe3f1e767b2136c5444dbfa9fa3f7944cc5e1983
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=23333 sha256=dc5436673c2d35b5c388f39fd250038bdea280ddc11af78084210471777ec53f
#   Stored in directory: /tmp/1000800000/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78542 sha256=dff5da14e7e16755b7f1000a3fdb1b50e576bb463fe9578461e84d2785dbc9e2
#   Stored in directory: /tmp/1000800000/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for google-apitools (setup.py) ... done
#   Created wheel for google-apitools: filename=google_apitools-0.5.31-py3-none-any.whl size=131022 sha256=55309f5adf2ad99fa2cf513dfb6ffee8fca30aaa7fcb83ce79ca2c5ac8333e03
#   Stored in directory: /tmp/1000800000/.cache/pip/wheels/04/b7/e0/9712f8c23a5da3d9d16fb88216b897bf60e85b12f5470f26ee
#   Building wheel for hdfs (setup.py) ... done
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34328 sha256=b935cf23a4c22549fcf903d0262cb65d5f982bffcc250dbe6f53f2754bf6f06a
#   Stored in directory: /tmp/1000800000/.cache/pip/wheels/e5/8d/b6/99c1c0a3ac5788c866b0ecd3f48b0134a5910e6ed26011800b
#   Building wheel for pyjsparser (setup.py) ... done
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25983 sha256=e5ee003931c43ce80d1058d0887e748031b8c66c63f16559431eb6b8fc66684e
#   Stored in directory: /tmp/1000800000/.cache/pip/wheels/5e/81/26/5956478df303e2bf5a85a5df595bb307bd25948a4bab69f7c7
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=fb4236705b6955052e130850dcdaccc5179b867da7692820556ba0036b4244da
#   Stored in directory: /tmp/1000800000/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built pyfarmhash crcmod dill google-apitools hdfs pyjsparser docopt
# Installing collected packages: pyjsparser, pyfarmhash, libclang, flatbuffers, docopt, crcmod, zstandard, uritemplate, tzlocal, tensorflow-estimator, sqlparse, shapely, pydot, pyarrow, protobuf, overrides, orjson, objsize, ml-dtypes, keras, joblib, httplib2, google-crc32c, fasteners, fastavro, dnspython, dill, pymongo, proto-plus, oauth2client, js2py, hdfs, google-resumable-media, google-auth, tensorflow-metadata, grpcio-status, google-auth-httplib2, google-apitools, google-api-core, apache-beam, tensorboard, grpc-google-iam-v1, google-cloud-core, google-api-python-client, tensorflow, google-cloud-vision, google-cloud-videointelligence, google-cloud-storage, google-cloud-spanner, google-cloud-resource-manager, google-cloud-recommendations-ai, google-cloud-pubsub, google-cloud-language, google-cloud-dlp, google-cloud-datastore, google-cloud-bigtable, google-cloud-bigquery-storage, google-cloud-bigquery, tensorflow-serving-api, google-cloud-pubsublite, google-cloud-aiplatform, tfx-bsl, tensorflow-data-validation
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 11.0.0
#     Uninstalling pyarrow-11.0.0:
#       Successfully uninstalled pyarrow-11.0.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.12
#     Uninstalling protobuf-4.21.12:
#       Successfully uninstalled protobuf-4.21.12
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.1.0
#     Uninstalling ml-dtypes-0.1.0:
#       Successfully uninstalled ml-dtypes-0.1.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.6.0
#     Uninstalling google-auth-2.6.0:
#       Successfully uninstalled google-auth-2.6.0
#   Attempting uninstall: tensorflow-metadata
#     Found existing installation: tensorflow-metadata 1.13.1
#     Uninstalling tensorflow-metadata-1.13.1:
#       Successfully uninstalled tensorflow-metadata-1.13.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.2
#     Uninstalling tensorboard-2.12.2:
#       Successfully uninstalled tensorboard-2.12.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# watson-nlp 4.1.0 requires pyarrow==11.0.0, but you have pyarrow 10.0.1 which is incompatible.
# watson-core 2.1.0 requires protobuf<5,>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# tf2onnx 1.13.0 requires flatbuffers<3.0,>=1.12, but you have flatbuffers 23.5.26 which is incompatible.
# tensorflow-text 2.12.0 requires tensorflow<2.13,>=2.12.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.14.0 which is incompatible.
# onnx 1.13.1 requires protobuf>=4.21, but you have protobuf 3.20.3 which is incompatible.
# autoai-ts-libs 3.0.4 requires tensorflow<2.13,>=2.7.0; python_version >= "3.9", but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed apache-beam-2.51.0 crcmod-1.7 dill-0.3.1.1 dnspython-2.4.2 docopt-0.6.2 fastavro-1.8.4 fasteners-0.19 flatbuffers-23.5.26 google-api-core-2.12.0 google-api-python-client-1.12.11 google-apitools-0.5.31 google-auth-2.23.3 google-auth-httplib2-0.1.1 google-cloud-aiplatform-1.35.0 google-cloud-bigquery-3.12.0 google-cloud-bigquery-storage-2.22.0 google-cloud-bigtable-2.21.0 google-cloud-core-2.3.3 google-cloud-datastore-2.18.0 google-cloud-dlp-3.12.3 google-cloud-language-2.11.1 google-cloud-pubsub-2.18.4 google-cloud-pubsublite-1.8.3 google-cloud-recommendations-ai-0.10.5 google-cloud-resource-manager-1.10.4 google-cloud-spanner-3.40.1 google-cloud-storage-2.12.0 google-cloud-videointelligence-2.11.4 google-cloud-vision-3.4.5 google-crc32c-1.5.0 google-resumable-media-2.6.0 grpc-google-iam-v1-0.12.6 grpcio-status-1.48.2 hdfs-2.7.3 httplib2-0.22.0 joblib-1.3.2 js2py-0.74 keras-2.14.0 libclang-16.0.6 ml-dtypes-0.2.0 oauth2client-4.1.3 objsize-0.6.1 orjson-3.9.10 overrides-6.5.0 proto-plus-1.22.3 protobuf-3.20.3 pyarrow-10.0.1 pydot-1.4.2 pyfarmhash-0.3.2 pyjsparser-2.7.1 pymongo-4.5.0 shapely-2.0.2 sqlparse-0.4.4 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-data-validation-1.14.0 tensorflow-estimator-2.14.0 tensorflow-metadata-1.14.0 tensorflow-serving-api-2.14.0 tfx-bsl-1.14.0 tzlocal-5.2 uritemplate-3.0.1 zstandard-0.21.0
# Collecting ibm-watson-studio-pipelines==0.2.12
#   Downloading ibm_watson_studio_pipelines-0.2.12-py3-none-any.whl (30 kB)
# Requirement already satisfied: requests>=2.25.1 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-watson-studio-pipelines==0.2.12) (2.29.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-watson-studio-pipelines==0.2.12) (4.4.0)
# Collecting responses>=0.13.4
#   Downloading responses-0.23.3-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: ibm-cos-sdk>=2.10.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-watson-studio-pipelines==0.2.12) (2.12.0)
# Requirement already satisfied: attrs>=21.2.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-watson-studio-pipelines==0.2.12) (22.1.0)
# Requirement already satisfied: pytest>=6.2.5 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-watson-studio-pipelines==0.2.12) (7.1.2)
# Requirement already satisfied: ibm-cloud-sdk-core>=3.11.3 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-watson-studio-pipelines==0.2.12) (3.16.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.5.3 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-cloud-sdk-core>=3.11.3->ibm-watson-studio-pipelines==0.2.12) (2.8.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-cloud-sdk-core>=3.11.3->ibm-watson-studio-pipelines==0.2.12) (2.4.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-cloud-sdk-core>=3.11.3->ibm-watson-studio-pipelines==0.2.12) (1.26.15)
# Requirement already satisfied: jmespath<1.0.0,>=0.10.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-cos-sdk>=2.10.0->ibm-watson-studio-pipelines==0.2.12) (0.10.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.12.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-cos-sdk>=2.10.0->ibm-watson-studio-pipelines==0.2.12) (2.12.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.12.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from ibm-cos-sdk>=2.10.0->ibm-watson-studio-pipelines==0.2.12) (2.12.0)
# Requirement already satisfied: iniconfig in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from pytest>=6.2.5->ibm-watson-studio-pipelines==0.2.12) (1.1.1)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from pytest>=6.2.5->ibm-watson-studio-pipelines==0.2.12) (23.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from pytest>=6.2.5->ibm-watson-studio-pipelines==0.2.12) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from pytest>=6.2.5->ibm-watson-studio-pipelines==0.2.12) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from pytest>=6.2.5->ibm-watson-studio-pipelines==0.2.12) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests>=2.25.1->ibm-watson-studio-pipelines==0.2.12) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests>=2.25.1->ibm-watson-studio-pipelines==0.2.12) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from requests>=2.25.1->ibm-watson-studio-pipelines==0.2.12) (2.0.4)
# Collecting types-PyYAML
#   Downloading types_PyYAML-6.0.12.12-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from responses>=0.13.4->ibm-watson-studio-pipelines==0.2.12) (6.0)
# Collecting requests>=2.25.1
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 28.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT23.1-Premium/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.5.3->ibm-cloud-sdk-core>=3.11.3->ibm-watson-studio-pipelines==0.2.12) (1.16.0)
# Installing collected packages: types-PyYAML, requests, responses, ibm-watson-studio-pipelines
#   Attempting uninstall: requests
#     Found existing installation: requests 2.29.0
#     Uninstalling requests-2.29.0:
#       Successfully uninstalled requests-2.29.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# watson-core 2.1.0 requires protobuf<5,>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# tf2onnx 1.13.0 requires flatbuffers<3.0,>=1.12, but you have flatbuffers 23.5.26 which is incompatible.
# autoai-ts-libs 3.0.4 requires tensorflow<2.13,>=2.7.0; python_version >= "3.9", but you have tensorflow 2.14.0 which is incompatible.
# Successfully installed ibm-watson-studio-pipelines-0.2.12 requests-2.31.0 responses-0.23.3 types-PyYAML-6.0.12.12
# Collecting python-dotenv==1.0.0
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
from botocore.client import Config
from sklearn.model_selection import train_test_split
from dataclasses import dataclass
import tensorflow_data_validation as tfdv
import numpy as np
import pandas as pd
from ibm_watson_studio_pipelines import WSPipelines
import warnings


warnings.filterwarnings("ignore")
# Out:
# 2023-10-27 13:15:59.297635: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 13:15:59.297683: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 13:15:59.297714: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-27 13:16:00.933364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Loading Variables and Utils from common python file
#
# In this section we load the variables and functions from the common python file. This file contains the variables and functions that are common to all the notebooks in this project.

# %%
import vars_and_utils as vars_and_utils

# %% [markdown]
# ## Load the Training Data
#
# this will check if the training data exists within a defined db2 table. If it does not exist, it will load the data from the web and store it in the project space as a .csv file.

# %%
gcr_df = vars_and_utils.load_german_credit_risk_data()

## Encode for ease of use with OpenScale
gcr_df['Risk'] = gcr_df['Risk'].map({'Risk':1,'No Risk':0})
gcr_df.head()
# Out:
# not implemented
# Error while loading data from db2. downloading csv file to filesystem instead
# Downloaded and saved as data/german_credit_data_biased_training.csv
# loading data to pandas dataframe
#   CheckingStatus  LoanDuration           CreditHistory LoanPurpose  \
# 0       0_to_200            31    credits_paid_to_date       other
# 1         less_0            18    credits_paid_to_date     car_new
# 2         less_0            15  prior_payments_delayed   furniture
# 3       0_to_200            28    credits_paid_to_date  retraining
# 4    no_checking            28  prior_payments_delayed   education
#
#    LoanAmount ExistingSavings EmploymentDuration  InstallmentPercent     Sex  \
# 0        1889      100_to_500             less_1                   3  female
# 1         462        less_100             1_to_4                   2  female
# 2         250        less_100             1_to_4                   2    male
# 3        3693        less_100          greater_7                   3    male
# 4        6235     500_to_1000          greater_7                   3    male
#
#   OthersOnLoan  ...       OwnsProperty Age  InstallmentPlans Housing  \
# 0         none  ...  savings_insurance  32              none     own
# 1         none  ...  savings_insurance  37            stores     own
# 2         none  ...        real_estate  28              none     own
# 3         none  ...  savings_insurance  32              none     own
# 4         none  ...            unknown  57              none     own
#
#   ExistingCreditsCount      Job Dependents  Telephone ForeignWorker Risk
# 0                    1  skilled          1       none           yes    0
# 1                    2  skilled          1       none           yes    0
# 2                    2  skilled          1        yes            no    0
# 3                    1  skilled          1       none           yes    0
# 4                    2  skilled          1       none           yes    1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Validation

# %%
@dataclass
class Datavalidation:
    """
    
    Data Validation Class
    
    """
    dataframe : pd.DataFrame
    mask_per :int
    
    
    def split_data(self,seed=32):
        """
        Split Data into Train and Test Splits
        
        """
        np.random.seed(seed)
        mask = np.random.rand(len(self.dataframe)) <= self.mask_per
        training_data = gcr_df[mask]
        testing_data = gcr_df[~mask]

        print(f"No. of training examples: {training_data.shape[0]}")
        print(f"No. of testing examples: {testing_data.shape[0]}")
        
        return training_data, testing_data
    
    # TODO: Replace with Db2/fileystem
    def save_data_in_filesystem(self,df,filename):
        """
        Save Data in Filesystem

        Passed filename should involve path

        """
        try:
            df.to_csv(filename,index=False)
            print(f"File {filename} persisted successfully")
        except Exception as e:
            print(e)
            print(f"File serialization for {filename} failed")
    
    def generate_statistics(self,df):
        """
        
        Generate Statistics on a given Dataframe
        
        """
        train_stats = tfdv.generate_statistics_from_dataframe(df)
        tfdv.visualize_statistics(train_stats)
        return train_stats
    
    def inferSchema(self,stats):
        
        """
        InferSchema on a given Dataframe
        
        """
        schema = tfdv.infer_schema(statistics=stats)
        tfdv.display_schema(schema=schema)
        return schema
    
    def compare_statistics(self,lhs,rhs):
        """
        
        Compare Statistics between a test dataframe and reference Schema
        
        """
        # Compare evaluation data with training data
        tfdv.visualize_statistics(lhs_statistics=lhs, rhs_statistics=rhs,
                                  lhs_name='TEST_DATASET', rhs_name='TRAIN_DATASET')
        
        
    def check_for_anomalies(self,testable_stats,ref_schema):
        """
        
        Check for any anomalies based on statistics and schema and values
        
        """
        anomalies = tfdv.validate_statistics(statistics=testable_stats, schema=ref_schema)
        tfdv.display_anomalies(anomalies)
        if len(anomalies.anomaly_info.items()) > 0:
            logger.error("Anomalies found in dataset...")
            logger.error(str(self.anomalies.anomaly_info.items()))
            return True
        else:
            return False

# %% [markdown]
# ###  Split Data into Train and Eval Splits to Check for Consistency

# %%
classvalidate = Datavalidation(dataframe=gcr_df,mask_per=0.8) 

training_data, testing_data = classvalidate.split_data()
# Out:
# No. of training examples: 3995
# No. of testing examples: 1005

# %% [markdown]
# ## Generate Training Stats on both Splits

# %%
train_stats = classvalidate.generate_statistics(training_data)
test_stats = classvalidate.generate_statistics(testing_data)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ## Infer Data Schemas

# %%
train_schema = classvalidate.inferSchema(train_stats)
test_schema = classvalidate.inferSchema(test_stats)
# Out:
#                               Type  Presence Valency                Domain
# Feature name
# 'CheckingStatus'            STRING  required              'CheckingStatus'
# 'LoanDuration'                 INT  required                             -
# 'CreditHistory'             STRING  required               'CreditHistory'
# 'LoanPurpose'               STRING  required                 'LoanPurpose'
# 'LoanAmount'                   INT  required                             -
# 'ExistingSavings'           STRING  required             'ExistingSavings'
# 'EmploymentDuration'        STRING  required          'EmploymentDuration'
# 'InstallmentPercent'           INT  required                             -
# 'Sex'                       STRING  required                         'Sex'
# 'OthersOnLoan'              STRING  required                'OthersOnLoan'
# 'CurrentResidenceDuration'     INT  required                             -
# 'OwnsProperty'              STRING  required                'OwnsProperty'
# 'Age'                          INT  required                             -
# 'InstallmentPlans'          STRING  required            'InstallmentPlans'
# 'Housing'                   STRING  required                     'Housing'
# 'ExistingCreditsCount'         INT  required                             -
# 'Job'                       STRING  required                         'Job'
# 'Dependents'                   INT  required                             -
# 'Telephone'                 STRING  required                   'Telephone'
# 'ForeignWorker'             STRING  required               'ForeignWorker'
# 'Risk'                         INT  required                             -
# '__index_level_0__'            INT  required                             -
#                                                                                                                                                    Values
# Domain
# 'CheckingStatus'                                                                                       '0_to_200', 'greater_200', 'less_0', 'no_checking'
# 'CreditHistory'                             'all_credits_paid_back', 'credits_paid_to_date', 'no_credits', 'outstanding_credit', 'prior_payments_delayed'
# 'LoanPurpose'         'appliances', 'business', 'car_new', 'car_used', 'education', 'furniture', 'other', 'radio_tv', 'repairs', 'retraining', 'vacation'
# 'ExistingSavings'                                                                      '100_to_500', '500_to_1000', 'greater_1000', 'less_100', 'unknown'
# 'EmploymentDuration'                                                                              '1_to_4', '4_to_7', 'greater_7', 'less_1', 'unemployed'
# 'Sex'                                                                                                                                    'female', 'male'
# 'OthersOnLoan'                                                                                                        'co-applicant', 'guarantor', 'none'
# 'OwnsProperty'                                                                                 'car_other', 'real_estate', 'savings_insurance', 'unknown'
# 'InstallmentPlans'                                                                                                               'bank', 'none', 'stores'
# 'Housing'                                                                                                                           'free', 'own', 'rent'
# 'Job'                                                                                    'management_self-employed', 'skilled', 'unemployed', 'unskilled'
# 'Telephone'                                                                                                                                 'none', 'yes'
# 'ForeignWorker'                                                                                                                               'no', 'yes'
#                               Type  Presence Valency                Domain
# Feature name
# 'CheckingStatus'            STRING  required              'CheckingStatus'
# 'LoanDuration'                 INT  required                             -
# 'CreditHistory'             STRING  required               'CreditHistory'
# 'LoanPurpose'               STRING  required                 'LoanPurpose'
# 'LoanAmount'                   INT  required                             -
# 'ExistingSavings'           STRING  required             'ExistingSavings'
# 'EmploymentDuration'        STRING  required          'EmploymentDuration'
# 'InstallmentPercent'           INT  required                             -
# 'Sex'                       STRING  required                         'Sex'
# 'OthersOnLoan'              STRING  required                'OthersOnLoan'
# 'CurrentResidenceDuration'     INT  required                             -
# 'OwnsProperty'              STRING  required                'OwnsProperty'
# 'Age'                          INT  required                             -
# 'InstallmentPlans'          STRING  required            'InstallmentPlans'
# 'Housing'                   STRING  required                     'Housing'
# 'ExistingCreditsCount'         INT  required                             -
# 'Job'                       STRING  required                         'Job'
# 'Dependents'                   INT  required                             -
# 'Telephone'                 STRING  required                   'Telephone'
# 'ForeignWorker'             STRING  required               'ForeignWorker'
# 'Risk'                         INT  required                             -
# '__index_level_0__'            INT  required                             -
#                                                                                                                                                    Values
# Domain
# 'CheckingStatus'                                                                                       '0_to_200', 'greater_200', 'less_0', 'no_checking'
# 'CreditHistory'                             'all_credits_paid_back', 'credits_paid_to_date', 'no_credits', 'outstanding_credit', 'prior_payments_delayed'
# 'LoanPurpose'         'appliances', 'business', 'car_new', 'car_used', 'education', 'furniture', 'other', 'radio_tv', 'repairs', 'retraining', 'vacation'
# 'ExistingSavings'                                                                      '100_to_500', '500_to_1000', 'greater_1000', 'less_100', 'unknown'
# 'EmploymentDuration'                                                                              '1_to_4', '4_to_7', 'greater_7', 'less_1', 'unemployed'
# 'Sex'                                                                                                                                    'female', 'male'
# 'OthersOnLoan'                                                                                                        'co-applicant', 'guarantor', 'none'
# 'OwnsProperty'                                                                                 'car_other', 'real_estate', 'savings_insurance', 'unknown'
# 'InstallmentPlans'                                                                                                               'bank', 'none', 'stores'
# 'Housing'                                                                                                                           'free', 'own', 'rent'
# 'Job'                                                                                    'management_self-employed', 'skilled', 'unemployed', 'unskilled'
# 'Telephone'                                                                                                                                 'none', 'yes'
# 'ForeignWorker'                                                                                                                               'no', 'yes'

# %% [markdown]
# ## Compare Eval and Train Data

# %%
classvalidate.compare_statistics(lhs=test_stats,rhs=train_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ## Check For Data Anomalies

# %% [markdown]
# ### Check eval data for errors by validating the eval data stats using the previously inferred schema.

# %%
anomaly_status = classvalidate.check_for_anomalies(test_stats,train_schema)
anomaly_status
# Out:
# <h4 style="color:green;">No anomalies found.</h4>
# False

# %% [markdown]
# ## Save Train and Test Data for Data Preparation Stage

# %%
# TODO: Replace with Db2/fileystem
if not anomaly_status:
    classvalidate.save_data_in_filesystem(df=training_data,filename=vars_and_utils.train_data_path)
    classvalidate.save_data_in_filesystem(df=testing_data,filename=vars_and_utils.test_data_path)
# Out:
# File data/train_gcr.csv persisted successfully
# File data/test_gcr.csv persisted successfully

# %% [markdown]
# ## Check if the validation steps were successful
# This checks if anomalies were found and if the data was successfully split into train and eval splits and stored as files.

# %%
def validation_successfull(train_data_path, test_data_path):
    if anomaly_status: # no anomalies
        return False
    elif not os.path.exists(train_data_path): # train data file exists
        return False
    elif not os.path.exists(test_data_path): # test data file exists
        return False
    else:
        print ("validation of the data successfull")
        return True
    
validation_successfull(vars_and_utils.train_data_path, vars_and_utils.test_data_path)
# Out:
# validation of the data successfull
# True

# %% [markdown]
# ## Register the output variables for the next pipeine stage
# every notebook outputs a "was_successful" boolean variable. The logic behind this is different for every notebook and can be altered to fit the needs of the project.
# If needed additional variables can be created here but they also need to registered as output variables in the Watson Pipelines UI.

# %%
validation_params = {}
validation_params['was_succesfull'] = validation_successfull(vars_and_utils.train_data_path, vars_and_utils.test_data_path)

pipelines_client = WSPipelines.from_token(TOKEN)
pipelines_client.store_results(validation_params)
# Out:
# validation of the data successfull
# Running outside of Watson Studio Pipeline - storing results in the local filesystem for testing purposes...
#
#   output paths:
#     - "was_succesfull": .ibm_watson_studio_pipelines/results/was_succesfull
